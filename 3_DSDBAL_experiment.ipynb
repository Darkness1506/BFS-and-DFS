# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
age=[20,18,28,30,65,42,77,44,55,60,57,18]
income=[10000,20000,30000,35000,60000,40000,70000,42000,55000,96000,100000,55000]

# %%
print(np.mean(age))
print(np.mean(income))
# Out:
# 42.833333333333336
# 51083.333333333336

# %%
print(np.median(age))
print(np.median(income))
# Out:
# 43.0
# 48500.0

# %%
from scipy import stats
print(stats.mode(age))
print(stats.mode(income))
# Out:
# ModeResult(mode=np.int64(18), count=np.int64(2))
# ModeResult(mode=np.int64(55000), count=np.int64(2))

# %%
print(np.std(age))
print(np.std(income))
# Out:
# 19.243324961023642
# 26521.87252480907

# %%
print(np.max(age))
print(np.max(income))
# Out:
# 77
# 100000

# %%
print(np.min(age))
print(np.min(income))
# Out:
# 18
# 10000

# %%
df=pd.read_csv("Iris.csv")

print('Iris-setosa')
setosa= df['Species'] == 'Iris-setosa'
print(df[setosa].describe())

print('\nIris-versicolor')
versicolor= df['Species'] == 'Iris-versicolor'
print(df[versicolor].describe())

print('\nIris-virginica')
virginica = df['Species'] == 'Iris-virginica'
print (df[virginica].describe())
# Out:
# Iris-setosa
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000
#
# Iris-versicolor
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# ...
